# %%
import pandas as pd
import numpy as numpy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %% [markdown]
# # Problem Statement
# A retail company “ABC Private Limited” wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month. The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.

# %%
# Train dataset
df_train=pd.read_csv('train.csv')
df_train.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
#Test dataset
df_test=pd.read_csv('test.csv')
df_test.head(2)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN

# %%
# Merge dataset
df=pd.concat([df_train, df_test], ignore_index=True)
df.head(3)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0

# %%
# Change cetegorical data into numerical to make it ML ready
df['Gender']=df['Gender'].map({'F':0,'M':1})
df.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# ...

# %%
df.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age']=df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5, '51-55':6,'55+':7})
df.head(4)
# Out:
#    User_ID Product_ID  Gender  Age  Occupation City_Category  \
# 0  1000001  P00069042       0    1          10             A
# 1  1000001  P00248942       0    1          10             A
# 2  1000001  P00087842       0    1          10             A
# 3  1000001  P00085442       0    1          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0

# %%
# changing categorical data city_category to numerical data
df_cityCat=pd.get_dummies(df['City_Category'],drop_first=True)
df_cityCat.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City_Category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...

# %%
# merging  dummy and final dataset
df=pd.concat([df,df_cityCat],axis=1)
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  1000001  P00069042       0    1          10                          2
# 1  1000001  P00248942       0    1          10                          2
# 2  1000001  P00087842       0    1          10                          2
# 3  1000001  P00085442       0    1          10                          2
# 4  1000002  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase      B      C
# ...

# %%
# city_category dropped
df.drop('City_Category',axis=1,inplace=True)
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  1000001  P00069042       0    1          10                          2
# 1  1000001  P00248942       0    1          10                          2
# 2  1000001  P00087842       0    1          10                          2
# 3  1000001  P00085442       0    1          10                          2
# 4  1000002  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase
# 0    8370.0
# 1   15200.0
# ...

# %%
df[['B', 'C']] = df[['B', 'C']].astype(int)
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  1000001  P00069042       0    1          10                          2
# 1  1000001  P00248942       0    1          10                          2
# 2  1000001  P00087842       0    1          10                          2
# 3  1000001  P00085442       0    1          10                          2
# 4  1000002  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase  B  C
# 0    8370.0  0  0
# ...

# %%
# Handling null values
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# B                                  0
# C                                  0
# dtype: int64

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %%
df['Product_Category_1'].value_counts()
# Out:
# Product_Category_1
# 5     215950
# 1     200699
# 8     162294
# 11     34440
# 2      34056
# 6      29326
# 3      28791
# 4      16756
# 16     13933
# 15      8984
# 13      7930
# 10      7373
# 12      5610
# 7       5345
# 18      4436
# 20      2550
# 14      2186
# 19      1603
# 17       801
# 9        604
# Name: count, dtype: int64

# %%
# Replace by null values by mode for discrete features
df['Product_Category_1'].mode()[0]
# Out:
# 5

# %%
df['Product_Category_1']=df['Product_Category_1'].fillna(df['Product_Category_1'].mode()[0])

# %%
df.Product_Category_1.isnull().sum()
# Out:
# 0

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df.Product_Category_2.isnull().sum()
# Out:
# 0

# %%
df['Product_Category_3']=df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.Product_Category_2.isnull().sum()
# Out:
# 0

# %%
df['Stay_In_Current_City_Years'].unique()
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].str.replace("+","")

# %%
df.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  1000001  P00069042       0    1          10                          2
# 1  1000001  P00248942       0    1          10                          2
# 2  1000001  P00087842       0    1          10                          2
# 3  1000001  P00085442       0    1          10                          2
# 4  1000002  P00285442       1    7          16                          4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  B  C
# 0    8370.0  0  0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  int64
#  3   Age                         783667 non-null  int64
#  4   Occupation                  783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  object
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  int32
#  12  C                           783667 non-null  int32
# ...

# %%
df['Stay_In_Current_City_Years']=df['Stay_In_Current_City_Years'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 783667 entries, 0 to 783666
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  int64
#  3   Age                         783667 non-null  int64
#  4   Occupation                  783667 non-null  int64
#  5   Stay_In_Current_City_Years  783667 non-null  int32
#  6   Marital_Status              783667 non-null  int64
#  7   Product_Category_1          783667 non-null  int64
#  8   Product_Category_2          783667 non-null  float64
#  9   Product_Category_3          783667 non-null  float64
#  10  Purchase                    550068 non-null  float64
#  11  B                           783667 non-null  int32
#  12  C                           783667 non-null  int32
# ...

# %%
# Visualization
sns.pairplot(df)

# %%
#Visualization of Age vs Gender
plt.figure(figsize=(10,6))
sns.barplot(x='Age', y='Purchase', hue='Gender', data=df)
plt.title("Average Purchase by Age Group and Gender")
plt.xlabel("Age Group")
plt.ylabel("Average Purchase Amount")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# # Males have higher purchase than females

# %%
#Visualization of purchase with occupation
plt.figure(figsize=(10,6))
sns.barplot(x='Occupation', y='Purchase', hue='Gender', data=df)
plt.title("Average Purchase by Occupation and Gender")
plt.xlabel("Occupation")
plt.ylabel("Average Purchase Amount")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
#Visualization of Product_category1 with Purchase
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category_1', y='Purchase', hue='Gender', data=df,palette='viridis')
plt.title("Average Purchase by Occupation and Gender")
plt.xlabel("Occupation")
plt.ylabel("Average Purchase Amount")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
#Feature Scaling
df_test=df[df['Purchase'].isnull()]

# %%
df_train=df[~df['Purchase'].isnull()]

# %%
X=df_train.drop('Purchase',axis=1)

# %%
X.head()
# Out:
#    User_ID Product_ID  Gender  Age  Occupation  Stay_In_Current_City_Years  \
# 0  1000001  P00069042       0    1          10                           2
# 1  1000001  P00248942       0    1          10                           2
# 2  1000001  P00087842       0    1          10                           2
# 3  1000001  P00085442       0    1          10                           2
# 4  1000002  P00285442       1    7          16                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    B  C
# 0  0  0
# 1  0  0
# 2  0  0
# ...

# %%
X.shape
# Out:
# (550068, 12)

# %%
y=df_train['Purchase']

# %%
y.shape
# Out:
# (550068,)

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 430.4 kB/s eta 0:00:25
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
X_train.drop('Product_ID',axis=1,inplace=True)
X_test.drop('Product_ID',axis=1,inplace=True)

# %%
## feature Scaling 
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
# Model ready to train
